# %%
from sklearn.decomposition import PCA
import os
import cv2
import matplotlib.pyplot as plt # plt 用於顯示圖片
import matplotlib.image as mpimg # mpimg 用於讀取圖片

# %%
print(img.shape)
plt.axis('off')
i = 1
fig , ax = plt.subplots(4, 15, sharex=True, sharey=True)
path_name =".\Dataset_CvDl_Hw2\Q4_Image"
for item in os.listdir(path= path_name):
    img = cv2.cvtColor(cv2.imread(os.path.join(path_name,item)), cv2.COLOR_BGR2RGB)
    print(item.split('.'))
    #plt.imshow(img)
    blue,green,red = cv2.split(img)
    
    #plt.imshow(red)
    df_blue = blue/255
    df_green = green/255
    df_red = red/255
    pca_b = PCA(n_components=10)
    pca_b.fit(df_blue)
    trans_pca_b = pca_b.transform(df_blue)

    pca_g = PCA(n_components=10)
    pca_g.fit(df_green)
    trans_pca_g = pca_g.transform(df_green)
    pca_r = PCA(n_components=10)
    pca_r.fit(df_red)
    trans_pca_r = pca_r.transform(df_red)

#print(f"Blue Channel : {sum(pca_b.explained_variance_ratio_)}")
#print(f"Green Channel: {sum(pca_g.explained_variance_ratio_)}")
#print(f"Red Channel  : {sum(pca_r.explained_variance_ratio_)}")
    b_arr = pca_b.inverse_transform(trans_pca_b)
    g_arr = pca_g.inverse_transform(trans_pca_g)
    r_arr = pca_r.inverse_transform(trans_pca_r)
#print(b_arr.shape, g_arr.shape, r_arr.shape)
    img_reduced= cv2.merge((b_arr, g_arr, r_arr))
#print(img_reduced.shape)
     

    plt.subplot(4, 15, i)
    plt.imshow(img)
    #plt.title("Original Image")
    #plt.imshow(img)

    i = i+1
    plt.subplot(4, 15, i)
    plt.imshow(img_reduced)
    #plt.title("Reduced Image")
    i = i+1
plt.axis('off')   
plt.show()
# Out:
# (400, 400, 3)
# ['1', 'jpg']
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# ['10', 'jpg']
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# ['11', 'jpg']
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# ['12', 'jpg']
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# ['13', 'jpg']
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# ['14', 'jpg']
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# ['15', 'jpg']
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# ['16', 'jpg']
# ...

# %%
plt.axis('off')
plt.imshow(img)
img_reduced = cv2.normalize(img_reduced, None, 0, 255, norm_type=cv2.NORM_MINMAX, dtype=cv2.CV_8UC3)

cv2.imwrite('img_reduced01.jpg', img_reduced)
img1 = cv2.cvtColor(img, cv2.COLOR_BGR2GRAY)
img2 = cv2.cvtColor(img_reduced, cv2.COLOR_BGR2GRAY)

reconstruction_error =  np.linalg.norm(img1 - img2, axis=0).sum()
print(int(reconstruction_error))
# Out:
# 1251510

# %%
path_name =".\Dataset_CvDl_Hw2\Q4_Image"
for item in os.listdir(path= path_name):
    img = mpimg.imread(os.path.join(path_name,item))
    plt.imshow(img)
    plt.show()

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
from sklearn.decomposition import PCA
import cv2
from scipy.stats import stats
import matplotlib.image as mpimg

# %%
img = cv2.cvtColor(cv2.imread('.\\Dataset_CvDl_Hw2\\Q4_Image\\1.jpg'), cv2.COLOR_BGR2RGB)
plt.imshow(img)
plt.show()
df_img = img/255

pca = PCA(n_components=50)
pca.fit(df_img)
trans_pca = pca.transform(df_img)
print(trans_pca.shape)
# Out:
# (400, 400, 3)
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# ~\AppData\Local\Temp/ipykernel_25200/3421523434.py in <module>
#       5 print(df_img.shape)
#       6 pca = PCA(n_components=50)
# ----> 7 pca.fit(df_img)
#       8 trans_pca = pca.transform(df_img)
#       9 print(trans_pca.shape)
#
# ~\anaconda3\envs\hw2\lib\site-packages\sklearn\decomposition\_pca.py in fit(self, X, y)
#     380             Returns the instance itself.
#     381         """
# --> 382         self._fit(X)
#     383         return self
#     384
#
# ~\anaconda3\envs\hw2\lib\site-packages\sklearn\decomposition\_pca.py in _fit(self, X)
#     429
#     430         X = self._validate_data(
# --> 431             X, dtype=[np.float64, np.float32], ensure_2d=True, copy=self.copy
#     432         )
#     433
#
# ...
